# %% [markdown]
# # The Different GPS Test using Choi Control Invariant
# This notebook looks at how well the Choi control invariant model detects
# the sensor spoofing attacks.
#
# The data files can be found in the src\choi\ subdirectory. Only interim data will be
# available on github to preserve storage. For raw log files please contact me at
# srimoungchanh.bailey@ku.edu.
#
# ## Choi Control Invariant
# The Choi Control Invariant is a model for detecting attacks on sensor published in
# CCS 2018. A link to the paper can be found here:
# https://friends.cs.purdue.edu/pubs/CCS18.pdf

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget


import numpy as np
import pandas as pd
from tqdm.notebook import trange
from IPython.display import clear_output
from math import ceil

def choi(target, measure):
    #Model Parameters
    WindowSize = ceil(13.772*400) # seconds * updates/second in main loop
    ErrorThreshold = 119 # Choi multiplys by 100*100 in the ArduPilot implementation
                         # because the logs record in degrees while the AHRS backend
                         # treats the data as centidegrees. We don't need to scale
    
    A = np.array([[0.9937, -0.0043, -0.00032627],
                 [0.0025, 1.0000, -0.00000040826],
                 [0.0000031184, 0.0025, 1.0000]], dtype=float)
    B = np.array([[0.0025],
                  [0.00000384],
                  [0.0000000026001]], dtype=float)
    C = np.array([2.4376, 1.2423, 0.1229], dtype=float)
    D = 0
    
    err_sum = 0 #accumulated errors
    w_index = 0 #current index in window
    max_mse = 0 #max error
    inv_x = np.array([[0.0],
                      [0.0],
                      [0.0]], dtype=float)
    MSEs = []
    #Go through the dataset
    for index in trange(len(target), desc="Processing dataframe"):
        # y = Cx[i] + Du[i]
        inv_y = np.matmul(C, inv_x) + D*target[index]
        
        # x' = Ax[i] + Bu[i]
        inv_x = np.matmul(A, inv_x) + B*target[index]
        
        # error calculation
        error = inv_y - measure[index]
        err_sum += error**2
        mse = err_sum / (w_index + 1)
        if mse > max_mse:
            max_mse = mse
        w_index+=1
        if w_index >= WindowSize:
            w_index = 0
            err_sum = 0
        MSEs.append(mse)
    clear_output()
    return(MSEs)

# %% [markdown]
# ## 1) Loading 1m offset with 0.40 m/s/s slow rate Data

# %%
#Read in data file
data_dir = "../src/choi/"
file = "Live-C-Idle-Attack-1m-0_4mss.csv"
df = pd.read_csv(data_dir + file)

#All of the data is numeric and should be treated as such
df = df.apply(pd.to_numeric)

#Set index to be the timestamps so we can drop duplicate rows
#then reset index to be row number
df.set_index("TimeUS",inplace=True)
df = df.drop_duplicates()
df.reset_index(inplace=True)
df['TimeUS'] = pd.to_datetime(df['TimeUS'], unit='us')

attack_start = []
attack_end = []
attack_start.append(pd.to_datetime(184627473, unit='us'))
attack_end.append(pd.to_datetime(196199871, unit='us'))

df = df[df['TimeUS'] < attack_end[-1]].reset_index(drop=True)
TimeUS = []
TimeUS.append(df.TimeUS)

# %%
import matplotlib.pyplot as plt
MSEs = []

MSEs.append(choi(df.DesPitch, df.Pitch))
plt.figure(figsize=(16, 8), dpi=80)
plt.plot(df.TimeUS, MSEs[-1], label="Error")
plt.plot(df.TimeUS, df.DesPitch, label="Target Pitch")
plt.plot(df.TimeUS, df.Pitch, label="Measured Pitch")
plt.axvline(attack_start[-1], color='r')
plt.axhline(119, color='r')
plt.xlabel("Time (s)")
plt.ylabel("Pitch (deg)")
plt.title("Error during 1m Offset with 0.40m/s/s Attack")
plt.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## 2) Loading 1m offset with 0.25 m/s/s slow rate Data

# %%
#Read in data file
data_dir = "../src/choi/"
file = "Live-C-Idle-Attack-1m-0_25mss.csv"
df = pd.read_csv(data_dir + file)

#All of the data is numeric and should be treated as such
df = df.apply(pd.to_numeric)

#Set index to be the timestamps so we can drop duplicate rows
#then reset index to be row number
df.set_index("TimeUS",inplace=True)
df = df.drop_duplicates()
df.reset_index(inplace=True)
df['TimeUS'] = pd.to_datetime(df['TimeUS'], unit='us')

attack_start.append(pd.to_datetime(171902803, unit='us'))
attack_end.append(pd.to_datetime(184020977, unit='us'))

df = df[df['TimeUS'] < attack_end[-1]].reset_index(drop=True)
TimeUS.append(df.TimeUS)

# %%
MSEs.append(choi(df.DesPitch, df.Pitch))
plt.figure(figsize=(16, 8), dpi=80)
plt.plot(df.TimeUS, MSEs[-1], label="Error")
plt.plot(df.TimeUS, df.DesPitch, label="Target Pitch")
plt.plot(df.TimeUS, df.Pitch, label="Measured Pitch")
plt.axvline(attack_start[-1], color='r')
plt.axhline(119, color='r')
plt.xlabel("Time (s)")
plt.ylabel("Pitch (deg)")
plt.title("Error during 1m Offset with 0.25m/s/s Attack")
plt.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## 3) Loading 0.5m offset with 0.25 m/s/s slow rate Data

# %%
#Read in data file
data_dir = "../src/choi/"
file = "Live-C-Idle-Attack-0_5m-0_25mss.csv"
df = pd.read_csv(data_dir + file)

#All of the data is numeric and should be treated as such
df = df.apply(pd.to_numeric)

#Set index to be the timestamps so we can drop duplicate rows
#then reset index to be row number
df.set_index("TimeUS",inplace=True)
df = df.drop_duplicates()
df.reset_index(inplace=True)
df['TimeUS'] = pd.to_datetime(df['TimeUS'], unit='us')

attack_start.append(pd.to_datetime(162088483, unit='us'))
attack_end.append(pd.to_datetime(178158899, unit='us'))

df = df[df['TimeUS'] < attack_end[-1]].reset_index(drop=True)
TimeUS.append(df.TimeUS)

# %%
MSEs.append(choi(df.DesPitch, df.Pitch))
plt.figure(figsize=(16, 8), dpi=80)
plt.plot(df.TimeUS, MSEs[-1], label="Error")
plt.plot(df.TimeUS, df.DesPitch, label="Target Pitch")
plt.plot(df.TimeUS, df.Pitch, label="Measured Pitch")
plt.axvline(attack_start[-1], color='r')
plt.axhline(119, color='r')
plt.xlabel("Time (s)")
plt.ylabel("Pitch (deg)")
plt.title("Error during 0.5m Offset with 0.25m/s/s Attack")
plt.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## 4) Loading 0_5m offset with 0.10 m/s/s slow rate Data

# %%
#Read in data file
data_dir = "../src/choi/"
file = "Live-C-Idle-Attack-0_5m-0_1mss.csv"
df = pd.read_csv(data_dir + file)

#All of the data is numeric and should be treated as such
df = df.apply(pd.to_numeric)

#Set index to be the timestamps so we can drop duplicate rows
#then reset index to be row number
df.set_index("TimeUS",inplace=True)
df = df.drop_duplicates()
df.reset_index(inplace=True)
df['TimeUS'] = pd.to_datetime(df['TimeUS'], unit='us')

attack_start.append(pd.to_datetime(197240832, unit='us'))
attack_end.append(pd.to_datetime(212816567, unit='us'))

df = df[df['TimeUS'] < attack_end[-1]].reset_index(drop=True)
TimeUS.append(df.TimeUS)

# %%
MSEs.append(choi(df.DesPitch, df.Pitch))
plt.figure(figsize=(16, 8), dpi=80)
plt.plot(df.TimeUS, MSEs[-1], label="Error")
plt.plot(df.TimeUS, df.DesPitch, label="Target Pitch")
plt.plot(df.TimeUS, df.Pitch, label="Measured Pitch")
plt.axvline(attack_start[-1], color='r')
plt.axhline(119, color='r')
plt.xlabel("Time (s)")
plt.ylabel("Pitch (deg)")
plt.title("Error during 0.5m Offset with 0.10m/s/s Attack")
plt.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## 5) Loading 0.25m offset with 0.10 m/s/s slow rate Data

# %%
#Read in data file
data_dir = "../src/choi/"
file = "Live-C-Idle-Attack-0_25m-0_1mss.csv"
df = pd.read_csv(data_dir + file)

#All of the data is numeric and should be treated as such
df = df.apply(pd.to_numeric)

#Set index to be the timestamps so we can drop duplicate rows
#then reset index to be row number
df.set_index("TimeUS",inplace=True)
df = df.drop_duplicates()
df.reset_index(inplace=True)
df['TimeUS'] = pd.to_datetime(df['TimeUS'], unit='us')

attack_start.append(pd.to_datetime(172223342, unit='us'))
attack_end.append(pd.to_datetime(194779194, unit='us'))

df = df[df['TimeUS'] < attack_end[-1]].reset_index(drop=True)
TimeUS.append(df.TimeUS)

# %%
MSEs.append(choi(df.DesPitch, df.Pitch))
plt.figure(figsize=(16, 8), dpi=80)
plt.plot(df.TimeUS, MSEs[-1], label="Error")
plt.plot(df.TimeUS, df.DesPitch, label="Target Pitch")
plt.plot(df.TimeUS, df.Pitch, label="Measured Pitch")
plt.axvline(attack_start[-1], color='r')
plt.axhline(119, color='r')
plt.xlabel("Time (s)")
plt.ylabel("Pitch (deg)")
plt.title("Error during 0.25m Offset with 0.10m/s/s Attack")
plt.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## All of the MSEs plotted together

# %%
from matplotlib import dates

for i in range(len(TimeUS)):
    attack_start[i] -= TimeUS[i][0]
    attack_start[i] = float(attack_start[i].seconds)
    TimeUS[i] = TimeUS[i] - TimeUS[i][0]
    TimeUS[i] = [i.total_seconds() for i in TimeUS[i]]

# %%
from statistics import mean

appended_strings = ["(1.00m, 0.40m/s/s)", "(1.00m, 0.25m/s/s)", "(0.50m, 0.25m/s/s)", "(0.50m, 0.10m/s/s)", "(0.25m, 0.10m/s/s)"]
plt.figure(figsize=(16, 8), dpi=80)
for i in range(len(MSEs)):
    plt.plot(TimeUS[i], MSEs[i], label="Mission %i %s" % (i+1, appended_strings[i]))
plt.axvline(mean(attack_start), color='r')
plt.axhline(119, color='r')
plt.xlabel("Time (s)")
plt.ylabel("Error")
plt.title("MSE for Each Mission")
plt.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
